# %%
import FinanceDataReader as fdr
import platform
import mplfinance as mpf
from mplfinance.original_flavor import candlestick_ohlc
from datetime import datetime
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import OpenDartReader
from matplotlib import font_manager, rc

if platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')

matplotlib.rcParams['axes.unicode_minus'] = False

df_krx = fdr.StockListing('KRX')
df_krx.head()
# Out:
#      Code        ISU_CD      Name Market Dept   Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI        66200          1     1200
# 1  373220  KR7373220003  LG에너지솔루션  KOSPI       562000          1     2000
# 2  000660  KR7000660001    SK하이닉스  KOSPI        93600          1     1700
# 3  207940  KR7207940008  삼성바이오로직스  KOSPI       780000          2    -7000
# 4  051910  KR7051910008      LG화학  KOSPI       709000          3        0
#
#    ChagesRatio    Open    High     Low    Volume        Amount  \
# 0         1.85   66000   66200   65700  14431704  952251371400
# 1         0.36  563000  564000  555000    144616   80991541000
# 2         1.85   92800   94000   92000   3473641  324457640270
# 3        -0.89  788000  790000  779000     37125   29027688000
# 4         0.00  712000  714000  701000    151282  107240364080
#
#             Marcap      Stocks MarketId
# 0  395199604810000  5969782550      STK
# 1  131508000000000   234000000      STK
# 2   68141021364000   728002365      STK
# 3   55515720000000    71174000      STK
# 4   50049971187000    70592343      STK

# %%
stock_list = df_krx["Code"]
corp_nm = "현대차"

# %%
corp_code = df_krx[df_krx["Name"] == corp_nm]["Code"]
corp_code = corp_code.iloc[0]

# %%
stock_df = fdr.DataReader(symbol=corp_code, start=datetime(2020,1,1))

# %%
import OpenDartReader
api_key = "c3d9a5fef22af5e566ddf1bf10e8c27ca46d0b15"
dart = OpenDartReader(api_key)

# %%
dart.finstate(corp=stock_list[0], bsns_year=2022)
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 1   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 2   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 3   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 4   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 5   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 6   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 7   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 8   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 9   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 10  20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 11  20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 12  20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 13  20230307000542      11011      2022  00126380     005930    OFS    재무제표
# 14  20230307000542      11011      2022  00126380     005930    OFS    재무제표
# 15  20230307000542      11011      2022  00126380     005930    OFS    재무제표
# 16  20230307000542      11011      2022  00126380     005930    OFS    재무제표
# 17  20230307000542      11011      2022  00126380     005930    OFS    재무제표
# 18  20230307000542      11011      2022  00126380     005930    OFS    재무제표
# 19  20230307000542      11011      2022  00126380     005930    OFS    재무제표
# 20  20230307000542      11011      2022  00126380     005930    OFS    재무제표
# 21  20230307000542      11011      2022  00126380     005930    OFS    재무제표
# 22  20230307000542      11011      2022  00126380     005930    OFS    재무제표
# 23  20230307000542      11011      2022  00126380     005930    OFS    재무제표
# 24  20230307000542      11011      2022  00126380     005930    OFS    재무제표
# 25  20230307000542      11011      2022  00126380     005930    OFS    재무제표
#
#    sj_div  sj_nm  account_nm  ...                thstrm_dt  \
# 0      BS  재무상태표        유동자산  ...            2022.12.31 현재
# 1      BS  재무상태표       비유동자산  ...            2022.12.31 현재
# 2      BS  재무상태표        자산총계  ...            2022.12.31 현재
# 3      BS  재무상태표        유동부채  ...            2022.12.31 현재
# 4      BS  재무상태표       비유동부채  ...            2022.12.31 현재
# 5      BS  재무상태표        부채총계  ...            2022.12.31 현재
# 6      BS  재무상태표         자본금  ...            2022.12.31 현재
# 7      BS  재무상태표       이익잉여금  ...            2022.12.31 현재
# 8      BS  재무상태표        자본총계  ...            2022.12.31 현재
# 9      IS  손익계산서         매출액  ...  2022.01.01 ~ 2022.12.31
# 10     IS  손익계산서        영업이익  ...  2022.01.01 ~ 2022.12.31
# 11     IS  손익계산서  법인세차감전 순이익  ...  2022.01.01 ~ 2022.12.31
# 12     IS  손익계산서       당기순이익  ...  2022.01.01 ~ 2022.12.31
# 13     BS  재무상태표        유동자산  ...            2022.12.31 현재
# 14     BS  재무상태표       비유동자산  ...            2022.12.31 현재
# 15     BS  재무상태표        자산총계  ...            2022.12.31 현재
# 16     BS  재무상태표        유동부채  ...            2022.12.31 현재
# 17     BS  재무상태표       비유동부채  ...            2022.12.31 현재
# 18     BS  재무상태표        부채총계  ...            2022.12.31 현재
# 19     BS  재무상태표         자본금  ...            2022.12.31 현재
# 20     BS  재무상태표       이익잉여금  ...            2022.12.31 현재
# 21     BS  재무상태표        자본총계  ...            2022.12.31 현재
# 22     IS  손익계산서         매출액  ...  2022.01.01 ~ 2022.12.31
# 23     IS  손익계산서        영업이익  ...  2022.01.01 ~ 2022.12.31
# 24     IS  손익계산서  법인세차감전 순이익  ...  2022.01.01 ~ 2022.12.31
# 25     IS  손익계산서       당기순이익  ...  2022.01.01 ~ 2022.12.31
#
#           thstrm_amount frmtrm_nm                frmtrm_dt  \
# 0   218,470,581,000,000    제 53 기            2021.12.31 현재
# 1   229,953,926,000,000    제 53 기            2021.12.31 현재
# 2   448,424,507,000,000    제 53 기            2021.12.31 현재
# 3    78,344,852,000,000    제 53 기            2021.12.31 현재
# 4    15,330,051,000,000    제 53 기            2021.12.31 현재
# 5    93,674,903,000,000    제 53 기            2021.12.31 현재
# 6       897,514,000,000    제 53 기            2021.12.31 현재
# 7   337,946,407,000,000    제 53 기            2021.12.31 현재
# 8   354,749,604,000,000    제 53 기            2021.12.31 현재
# 9   302,231,360,000,000    제 53 기  2021.01.01 ~ 2021.12.31
# 10   43,376,630,000,000    제 53 기  2021.01.01 ~ 2021.12.31
# 11   46,440,474,000,000    제 53 기  2021.01.01 ~ 2021.12.31
# 12   55,654,077,000,000    제 53 기  2021.01.01 ~ 2021.12.31
# 13   59,062,658,000,000    제 53 기            2021.12.31 현재
# 14  201,021,092,000,000    제 53 기            2021.12.31 현재
# 15  260,083,750,000,000    제 53 기            2021.12.31 현재
# 16   46,086,047,000,000    제 53 기            2021.12.31 현재
# 17    4,581,512,000,000    제 53 기            2021.12.31 현재
# 18   50,667,559,000,000    제 53 기            2021.12.31 현재
# 19      897,514,000,000    제 53 기            2021.12.31 현재
# 20  204,388,016,000,000    제 53 기            2021.12.31 현재
# 21  209,416,191,000,000    제 53 기            2021.12.31 현재
# 22  211,867,483,000,000    제 53 기  2021.01.01 ~ 2021.12.31
# 23   25,319,329,000,000    제 53 기  2021.01.01 ~ 2021.12.31
# 24   29,691,920,000,000    제 53 기  2021.01.01 ~ 2021.12.31
# 25   25,418,778,000,000    제 53 기  2021.01.01 ~ 2021.12.31
#
#           frmtrm_amount bfefrmtrm_nm             bfefrmtrm_dt  \
# 0   218,163,185,000,000       제 52 기            2020.12.31 현재
# 1   208,457,973,000,000       제 52 기            2020.12.31 현재
# 2   426,621,158,000,000       제 52 기            2020.12.31 현재
# 3    88,117,133,000,000       제 52 기            2020.12.31 현재
# 4    33,604,094,000,000       제 52 기            2020.12.31 현재
# 5   121,721,227,000,000       제 52 기            2020.12.31 현재
# 6       897,514,000,000       제 52 기            2020.12.31 현재
# 7   293,064,763,000,000       제 52 기            2020.12.31 현재
# 8   304,899,931,000,000       제 52 기            2020.12.31 현재
# 9   279,604,799,000,000       제 52 기  2020.01.01 ~ 2020.12.31
# 10   51,633,856,000,000       제 52 기  2020.01.01 ~ 2020.12.31
# 11   53,351,827,000,000       제 52 기  2020.01.01 ~ 2020.12.31
# 12   39,907,450,000,000       제 52 기  2020.01.01 ~ 2020.12.31
# 13   73,553,416,000,000       제 52 기            2020.12.31 현재
# 14  177,558,768,000,000       제 52 기            2020.12.31 현재
# 15  251,112,184,000,000       제 52 기            2020.12.31 현재
# 16   53,067,303,000,000       제 52 기            2020.12.31 현재
# 17    4,851,149,000,000       제 52 기            2020.12.31 현재
# 18   57,918,452,000,000       제 52 기            2020.12.31 현재
# 19      897,514,000,000       제 52 기            2020.12.31 현재
# 20  188,774,335,000,000       제 52 기            2020.12.31 현재
# 21  193,193,732,000,000       제 52 기            2020.12.31 현재
# 22  199,744,705,000,000       제 52 기  2020.01.01 ~ 2020.12.31
# 23   31,993,162,000,000       제 52 기  2020.01.01 ~ 2020.12.31
# 24   38,704,492,000,000       제 52 기  2020.01.01 ~ 2020.12.31
# 25   30,970,954,000,000       제 52 기  2020.01.01 ~ 2020.12.31
#
#        bfefrmtrm_amount ord currency
# 0   198,215,579,000,000   1      KRW
# 1   180,020,139,000,000   3      KRW
# 2   378,235,718,000,000   5      KRW
# 3    75,604,351,000,000   7      KRW
# 4    26,683,351,000,000   9      KRW
# 5   102,287,702,000,000  11      KRW
# 6       897,514,000,000  13      KRW
# 7   271,068,211,000,000  17      KRW
# 8   275,948,016,000,000  21      KRW
# 9   236,806,988,000,000  23      KRW
# 10   35,993,876,000,000  25      KRW
# 11   36,345,117,000,000  27      KRW
# 12   26,407,832,000,000  29      KRW
# 13   73,798,549,000,000   2      KRW
# 14  155,865,878,000,000   4      KRW
# 15  229,664,427,000,000   6      KRW
# 16   44,412,904,000,000   8      KRW
# 17    1,934,799,000,000  10      KRW
# 18   46,347,703,000,000  12      KRW
# 19      897,514,000,000  15      KRW
# 20  178,284,102,000,000  19      KRW
# 21  183,316,724,000,000  22      KRW
# 22  166,311,191,000,000  24      KRW
# 23   20,518,974,000,000  26      KRW
# 24   20,451,923,000,000  28      KRW
# 25   15,615,018,000,000  30      KRW
#
# [26 rows x 21 columns]

# %%
dv = dart.report(corp=stock_list[0], bsns_year=2022, reprt_code="11011", key_word="배당")

dv_dps   = dv[dv['se'] == '주당 현금배당금(원)']
dv_eps   = dv[dv['se'].str.contains('주당순이익')]
dv_yield = dv[dv['se'].str.contains('현금배당수익률')]
dv_TD    = dv[dv['se'].str.contains('현금배당금총액')]

EPS = int(dv_eps[['thstrm']].iloc[0,0].replace(',','').strip()) # 주당순이익
DPS = int(dv_dps[['thstrm']].iloc[0,0].replace(',', '').strip()) # 주당 배당금
Yield = float(dv_yield[['thstrm']].iloc[0,0].replace(',','').strip())
TD = int(dv_TD[['thstrm']].iloc[0,0].replace(',', '').strip()) * 1000000 # 배당금총액. 백만원단위

pd.DataFrame({'종목코드':['005930'], '종목명':['삼성전자'], 
              'EPS':[EPS], 'DPS':[DPS], '배당수익률':[Yield], '배당금총액':[TD]})
# Out:
#      종목코드   종목명   EPS   DPS  배당수익률          배당금총액
# 0  005930  삼성전자  8057  1444    2.5  9809438000000

# %%
corp_book = dart.finstate_all(corp=stock_list[0], bsns_year=2022, fs_div="CFS", reprt_code="11011")
# Out:
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'

# %%
datetime.today().year -1
# Out:
# 2022

# %%
equity = int(corp_book.loc[corp_book['sj_div'].isin(['BS']) & corp_book['account_id'].isin(['ifrs-full_Equity']), 'thstrm_amount'].replace(",", "")) # 당기자본(자본총계)
liability = int(corp_book.loc[corp_book['sj_div'].isin(['BS']) & corp_book['account_id'].isin(['ifrs-full_Liabilities']), 'thstrm_amount'].replace(",", "")) # 당기부채(부채총계)
assets = equity + liability # 자산총계

# %%
profit = int(corp_book.loc[corp_book['sj_div'].isin(['IS']) & corp_book['account_id'].isin(['ifrs-full_ProfitLossAttributableToOwnersOfParent']), 'thstrm_amount'].replace(",", "")) # 당기순이익

# %%
corp_book[corp_book['sj_div'].isin(['CIS'])]
# Out:
#           rcept_no reprt_code bsns_year corp_code sj_div    sj_nm  \
# 71  20230307000542      11011      2022  00126380    CIS  포괄손익계산서
# 72  20230307000542      11011      2022  00126380    CIS  포괄손익계산서
# 73  20230307000542      11011      2022  00126380    CIS  포괄손익계산서
# 74  20230307000542      11011      2022  00126380    CIS  포괄손익계산서
# 75  20230307000542      11011      2022  00126380    CIS  포괄손익계산서
# 76  20230307000542      11011      2022  00126380    CIS  포괄손익계산서
# 77  20230307000542      11011      2022  00126380    CIS  포괄손익계산서
# 78  20230307000542      11011      2022  00126380    CIS  포괄손익계산서
# 79  20230307000542      11011      2022  00126380    CIS  포괄손익계산서
# 80  20230307000542      11011      2022  00126380    CIS  포괄손익계산서
# 81  20230307000542      11011      2022  00126380    CIS  포괄손익계산서
# 82  20230307000542      11011      2022  00126380    CIS  포괄손익계산서
# 83  20230307000542      11011      2022  00126380    CIS  포괄손익계산서
#
#                                            account_id  \
# 71                               ifrs-full_ProfitLoss
# 72                 ifrs-full_OtherComprehensiveIncome
# 73  dart_OtherComprehensiveIncomeThatWillNotBeRecl...
# 74                                       -표준계정코드 미사용-
# 75  dart_ShareOfOtherComprehensiveIncomeOfAssociat...
# 76  dart_OtherComprehensiveIncomeNetOfTaxGainsLoss...
# 77  dart_OtherComprehensiveIncomeThatWillBeReclass...
# 78  dart_ShareOfOtherComprehensiveIncomeOfAssociat...
# 79  ifrs-full_GainsLossesOnExchangeDifferencesOnTr...
# 80      ifrs-full_GainsLossesOnCashFlowHedgesNetOfTax
# 81                      ifrs-full_ComprehensiveIncome
# 82  ifrs-full_ComprehensiveIncomeAttributableToOwn...
# 83  ifrs-full_ComprehensiveIncomeAttributableToNon...
#
#                     account_nm account_detail thstrm_nm   thstrm_amount  \
# 71                   당기순이익(손실)              -    제 54 기  55654077000000
# 72                      기타포괄손익              -    제 54 기   4005664000000
# 73  후속적으로 당기손익으로 재분류되지 않는 포괄손익              -    제 54 기   -822137000000
# 74         기타포괄손익-공정가치금융자산평가손익              -    제 54 기  -1969498000000
# 75  관계기업 및 공동기업의 기타포괄손익에 대한 지분              -    제 54 기     -6318000000
# 76           순확정급여부채(자산) 재측정요소              -    제 54 기   1153679000000
# 77     후속적으로 당기손익으로 재분류되는 포괄손익              -    제 54 기   4827801000000
# 78  관계기업 및 공동기업의 기타포괄손익에 대한 지분              -    제 54 기    -44192000000
# 79                 해외사업장환산외환차이              -    제 54 기   4884886000000
# 80            현금흐름위험회피파생상품평가손익              -    제 54 기    -12893000000
# 81                       총포괄손익              -    제 54 기  59659741000000
# 82                  지배기업 소유주지분              -    제 54 기  58745107000000
# 83                       비지배지분              -    제 54 기    914634000000
#
#    frmtrm_nm   frmtrm_amount bfefrmtrm_nm bfefrmtrm_amount ord currency  \
# 71    제 53 기  39907450000000       제 52 기   26407832000000   0      KRW
# 72    제 53 기  10002299000000       제 52 기   -3673905000000   1      KRW
# 73    제 53 기   2508106000000       제 52 기    1788764000000   2      KRW
# 74    제 53 기   2980896000000       제 52 기    2502733000000   3      KRW
# 75    제 53 기     51816000000       제 52 기       5591000000   4      KRW
# 76    제 53 기   -524606000000       제 52 기    -719560000000   5      KRW
# 77    제 53 기   7494193000000       제 52 기   -5462669000000   6      KRW
# 78    제 53 기    160163000000       제 52 기     -48888000000   7      KRW
# 79    제 53 기   7283620000000       제 52 기   -5380375000000   8      KRW
# 80    제 53 기     50410000000       제 52 기     -33406000000   9      KRW
# 81    제 53 기  49909749000000       제 52 기   22733927000000  10      KRW
# 82    제 53 기  49037912000000       제 52 기   22374398000000  12      KRW
# 83    제 53 기    871837000000       제 52 기     359529000000  13      KRW
#
#    thstrm_add_amount
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 79
# 80
# 81
# 82
# 83

# %%
tmp = dart.report(corp=stock_list[0], bsns_year=2022, reprt_code="11011", key_word="주식총수")
total_stock = int(tmp[tmp["se"] == "합계"]["distb_stock_co"].iloc[0].replace(",",""))

# %%
EPS = profit/total_stock
PER = stock_df["Close"][-1] / EPS
BPS = equity / total_stock
PBR = stock_df["Close"][-1] / BPS
ROE = PBR / PER
ROA = profit / assets
DE = liability / assets

# %%
stock_df['ma20'] = stock_df['Close'].rolling(window=20).mean() # 20일 이동평균
stock_df['stddev'] = stock_df['Close'].rolling(window=20).std() # 20일 이동표준편차
stock_df['upper'] = stock_df['ma20'] + 2*stock_df['stddev'] # 상단밴드
stock_df['lower'] = stock_df['ma20'] - 2*stock_df['stddev'] # 하단밴드
stock_df['PB'] = (stock_df["Close"] - stock_df['lower']) / (stock_df["upper"] - stock_df['lower'])
stock_df['bandwidth'] = (stock_df["upper"] - stock_df['lower']) / (stock_df["ma20"])
stock_df['ma5'] = stock_df['Close'].rolling(window=5).mean() # 60일 이동평균
stock_df['ma60'] = stock_df['Close'].rolling(window=60).mean() # 60일 이동평균
stock_df['ma120'] = stock_df['Close'].rolling(window=120).mean() # 120일 이동평균



# 10일(거래일 기준으로 2주 동안) 기준의 현금흐름지표를 구하는 코드
stock_df['TP'] = (stock_df['High']+stock_df['Low']+stock_df['Close'])/3
stock_df['PMF'] = 0
stock_df['NMF'] = 0
for i in range(len(stock_df['Close'])-1):
    # 당일의 중심가격이 전일의 중심가격보다 크면 긍정적 현금흐름
    if stock_df['TP'].values[i] < stock_df['TP'].values[i+1]:
        stock_df['PMF'].values[i+1] = stock_df['TP'].values[i+1]*stock_df['Volume'].values[i+1]
        stock_df['NMF'].values[i+1] = 0
    # 당일의 중심가격이 전일의 중심가격보다 작거나 같으면 부정적 현금흐름
    else:
        stock_df['NMF'].values[i+1] = stock_df['TP'].values[i+1]*stock_df['Volume'].values[i+1]
        stock_df['PMF'].values[i+1] = 0
        
stock_df['MFR'] = stock_df['PMF'].rolling(window=10).sum()/stock_df['NMF'].rolling(window=10).sum()
stock_df['MFI10'] = 100 - 100/(1+stock_df['MFR'])
stock_df = stock_df[19:] # 20일 이동평균을 구했기 때문에 20번째 행부터 값이 들어가 있음
stock_df
# Out:
#               Open    High     Low   Close   Volume    Change      ma20  \
# Date
# 2020-01-31  128500  129500  124500  125000  1035126 -0.019608  119625.0
# 2020-02-03  123000  125000  121000  123500  1270442 -0.012000  119900.0
# 2020-02-04  123500  126000  122500  124000  1203992  0.004049  120300.0
# 2020-02-05  125000  126000  123500  124000  1032267  0.000000  120700.0
# 2020-02-06  125500  133000  125500  132000  1659774  0.064516  121525.0
# ...            ...     ...     ...     ...      ...       ...       ...
# 2023-05-12  207000  209500  205500  208500   539737  0.002404  199375.0
# 2023-05-15  207000  209000  204000  208000   594282 -0.002398  199830.0
# 2023-05-16  206500  207500  201000  202500   874247 -0.026442  200150.0
# 2023-05-17  202500  205500  202500  204500   550297  0.009877  200625.0
# 2023-05-18  207000  207000  205000  206500   475743  0.009780  201380.0
#
#                  stddev          upper          lower        PB  bandwidth  \
# Date
# 2020-01-31  6480.486905  132585.973810  106664.026190  0.707353   0.216693
# 2020-02-03  6524.447950  132948.895900  106851.104100  0.637943   0.217663
# 2020-02-04  6517.991295  133335.982591  107264.017409  0.641915   0.216725
# 2020-02-05  6485.611605  133671.223211  107728.776789  0.627205   0.214933
# 2020-02-06  6829.647059  135184.294118  107865.705882  0.883439   0.224798
# ...                 ...            ...            ...       ...        ...
# 2023-05-12  5837.435901  211049.871801  187700.128199  0.890797   0.117115
# 2023-05-15  6145.010813  212120.021626  187539.978374  0.832383   0.123005
# 2023-05-16  6107.070966  212364.141933  187935.858067  0.596200   0.122050
# 2023-05-17  6054.652409  212734.304817  188515.695183  0.660001   0.120716
# 2023-05-18  5778.963666  212937.927332  189822.072668  0.721493   0.114787
#
#                  ma5           ma60          ma120             TP  \
# Date
# 2020-01-31  129000.0            NaN            NaN  126333.333333
# 2020-02-03  127600.0            NaN            NaN  123166.666667
# 2020-02-04  126200.0            NaN            NaN  124166.666667
# 2020-02-05  124800.0            NaN            NaN  124500.000000
# 2020-02-06  125700.0            NaN            NaN  130166.666667
# ...              ...            ...            ...            ...
# 2023-05-12  206800.0  185721.666667  175376.666667  207833.333333
# 2023-05-15  207900.0  186310.000000  175697.500000  207000.000000
# 2023-05-16  207400.0  186696.666667  175985.000000  203666.666667
# 2023-05-17  206300.0  187121.666667  176310.000000  204166.666667
# 2023-05-18  206000.0  187593.333333  176647.500000  206166.666667
#
#                      PMF           NMF       MFR      MFI10
# Date
# 2020-01-31             0  130770918000  3.530886  77.929264
# 2020-02-03             0  156476106333  2.139849  68.151339
# 2020-02-04  149495673333             0  2.291268  69.616575
# 2020-02-05  128517241500             0  2.806793  73.731167
# 2020-02-06  216047249000             0  3.748981  78.942853
# ...                  ...           ...       ...        ...
# 2023-05-12             0  112175339833  1.579117  61.227041
# 2023-05-15             0  123016374000  1.797696  64.256301
# 2023-05-16             0  178054972333  1.912176  65.661420
# 2023-05-17  112352304166             0  1.906916  65.599282
# 2023-05-18   98082348500             0  1.918145  65.731658
#
# [817 rows x 20 columns]

# %%
up = stock_df[stock_df["Close"] >= stock_df["Open"]]
down = stock_df[stock_df["Close"] < stock_df["Open"]]

# %%
# mpf.plot(stock_df, type="candle", volume=True)
ma5 = mpf.make_addplot(stock_df["ma5"], color="orange", width=1.5)
ma20 = mpf.make_addplot(stock_df["ma20"], color="dodgerblue", width=1.5)
ma60 = mpf.make_addplot(stock_df["ma60"], color="grey", width=1.5)
ma120 = mpf.make_addplot(stock_df["ma120"], color="grey", width=1.5)

mpf.plot(
            stock_df,
            type='candle',
            addplot = [ma5, ma20, ma60, ma120],
            style='charles',
            title='Apple, March - 2020 (with SMA, EMA & RSI)',
            volume=True
        )
# Out:
# c:\Users\kohop\Documents\Projects\dev_projects\algo_trader\.venv\lib\site-packages\mplfinance\_arg_validators.py:83: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
width = .3
width2 = .03

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 10), sharex=True)

axes[0].bar(up.index, up["Close"]-up["Open"], width, bottom=up["Open"], color="red")
axes[0].bar(up.index, up["High"]-up["Close"], width2, bottom=up["Close"], color="red")
axes[0].bar(up.index, up["Low"]-up["Open"], width2, bottom=up["Open"], color="red")
  
# Plotting down prices of the stock
axes[0].bar(down.index, down["Close"]-down["Open"], width, bottom=down["Open"], color="blue")
axes[0].bar(down.index, down["High"]-down["Close"], width2, bottom=down["Close"], color="blue")
axes[0].bar(down.index, down["Low"]-down["Open"], width2, bottom=down["Open"], color="blue")

axes[0].set_title(f'{corp_nm}(주가차트)')

axes[1].bar(stock_df.index, stock_df['Volume'], label='거래량')
# Out:
# <BarContainer object of 815 artists>

# %%
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(10, 20), sharex=True)


axes[0].plot(stock_df.index, stock_df['Close'], label='종가')
axes[0].plot(stock_df.index, stock_df['upper'], linestyle='dashed', label='Upper band')
axes[0].plot(stock_df.index, stock_df['ma20'], linestyle='dashed', label='Moving Average 20')
axes[0].plot(stock_df.index, stock_df['lower'], linestyle='dashed', label='Lower band')

axes[0].set_title(f'{corp_nm}({corp_code})의 볼린저 밴드(20일, 2 표준편차)')

for i in range(stock_df.shape[0]):
    if stock_df['PB'].values[i] > 0.8 and stock_df['MFI10'].values[i] > 80:
        axes[0].plot(stock_df.index.values[i], stock_df['Close'].values[i], 'r^')
    elif stock_df['PB'].values[i] < 0.2 and stock_df['MFI10'].values[i] < 20:
        axes[0].plot(stock_df.index.values[i], stock_df['Close'].values[i], 'bv')
axes[0].legend(loc='best')


axes[1].plot(stock_df.index, stock_df['PB'], label='%B', color="purple")
axes[1].grid(True)
axes[1].legend(loc='best')


axes[2].plot(stock_df.index, stock_df['bandwidth'], label='밴드폭', color="brown")
axes[2].grid(True)
axes[2].legend(loc='best')


axes[3].plot(stock_df.index, stock_df['MFI10'], label='MFI10', color="orange")
axes[3].axhline(y=80, color="black", linestyle='dotted')
axes[3].axhline(y=20, color="black", linestyle='dotted')
axes[3].grid(True)
axes[3].legend(loc='best')

# %%
##### analysis
comment = "볼린저 벤드는 주가의 변동성을 이용한 추세매매에 사용하는 분석 도구입니다. 표준 편차를 이용하여 변동성을 계산합니다. \n"
if stock_df[:int(len(stock_df)/2)]["bandwidth"].mean() > stock_df[int(len(stock_df)/2):]["bandwidth"].mean() :
    comment = comment + "볼린저 밴드의 Bandwidth 가 감소하고 있습니다. 변동성이 낮아지고 있습니다. \n"
else :
    comment = comment + "볼린저 밴드의 Bandwidth 가 증가하고 있습니다. 변동성이 증가하고 있습니다. \n"

if stock_df[-1:]["Close"].iloc[0] < stock_df[-1:]["upper"].iloc[0] and stock_df[-1:]["Close"].iloc[0] > stock_df[-1:]["lower"].iloc[0] :
    comment = comment + "볼린저 밴드의 내부에 있습니다. 박스권 입니다. \n"
    if stock_df[-1:]["Close"].iloc[0] < stock_df[-1:]["ma20"].iloc[0] :
        comment = comment + "볼린저 밴드의 하단 입니다. 매수를 추천합니다. \n"
elif stock_df[-1:]["Close"].iloc[0] > stock_df[-1:]["upper"].iloc[0] and stock_df[:int(len(stock_df)/2)]["bandwidth"].mean() < stock_df[int(len(stock_df)/2):]["bandwidth"].mean() :
    comment = comment + "볼린저 밴드의 상단 이탈이지만 변동성이 큽니다. 호재가 있는지 확인 후 매수하세요. \n"
elif stock_df[-1:]["Close"].iloc[0] > stock_df[-1:]["upper"].iloc[0] and stock_df[:int(len(stock_df)/2)]["bandwidth"].mean() > stock_df[int(len(stock_df)/2):]["bandwidth"].mean() :
    comment = comment + "볼린저 밴드의 상단 이탈이지만 변동성이 작습니다. 대세 상승일 수 있습니다. \n"
else :
    comment = comment + "볼린저 밴드의 박스권 밖 이탈입니다. 호재, 악재 여부를 확인 후 매수하세요. \n"

if stock_df[-1:]['MFI10'].iloc[0] <= 20 :
    comment = comment + "MFI 지수가 20 아래입니다. 거래량이 죽었습니다. \n"
    if stock_df[-1:]["Close"].iloc[0] < stock_df[-1:]["ma20"].iloc[0] :
        comment = comment + "매도를 고려해야 합니다. \n"
    else :
        comment = comment + "과잉 매도입니다. \n"
elif stock_df[-1:]['MFI10'].iloc[0] >= 80 :   
    comment = comment + "MFI 지수가 80 위입니다. 과열 되었습니다. 과잉 매수 중입니다. \n"
    if stock_df[-1:]["Close"].iloc[0] > stock_df[-1:]["ma20"].iloc[0] :
        comment = comment + "추격 매수를 고려해야 합니다. \n"
    else :
        comment = comment + "과잉 매수입니다. \n"
comment
# Out:
# '볼린저 벤드는 주가의 변동성을 이용한 추세매매에 사용하는 분석 도구입니다. 표준 편차를 이용하여 변동성을 계산합니다. \n볼린저 밴드의 Bandwidth 가 감소하고 있습니다. 변동성이 낮아지고 있습니다. \n볼린저 밴드의 내부에 있습니다. 박스권 입니다. \n'
